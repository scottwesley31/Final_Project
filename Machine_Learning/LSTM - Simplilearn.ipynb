# %% [markdown]
# # Long Short Term Memory Network (LSTM)

# %% [markdown]
# ## Stock Price Prediction

# %% [markdown]
# Reference: https://www.simplilearn.com/tutorials/machine-learning-tutorial/stock-price-prediction-using-machine-learning

# %%
# Import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read the dataset into a pandas dataframe
df1 = pd.read_csv('../../launchit.csv')
df1.head()
# Out:
#          Date    Open   High    Low  Close  Adj Close    Volume  TCKR  sector  \
# 0  2019-12-19  11.000  11.96  10.50  10.70      10.70   89400.0  INDO  Energy
# 1  2019-12-20  10.808  12.49   9.25   9.65       9.65  503000.0  INDO  Energy
# 2  2019-12-23   8.790   8.79   7.25   7.81       7.81  117400.0  INDO  Energy
# 3  2019-12-24   7.500   7.64   6.00   6.41       6.41  102800.0  INDO  Energy
# 4  2019-12-26   6.420   7.72   6.42   7.41       7.41   78400.0  INDO  Energy
#
#         industry    country  growth_rate  target_median_price  \
# 0  Oil & Gas E&P  Indonesia        1.206                 15.0
# 1  Oil & Gas E&P  Indonesia        1.206                 15.0
# 2  Oil & Gas E&P  Indonesia        1.206                 15.0
# 3  Oil & Gas E&P  Indonesia        1.206                 15.0
# 4  Oil & Gas E&P  Indonesia        1.206                 15.0
#
#    target_mean_price  target_high_price
# 0               15.0               15.0
# 1               15.0               15.0
# 2               15.0               15.0
# 3               15.0               15.0
# 4               15.0               15.0

# %%
# Make a new copy of the dataset_train 
dataset_train = df1.copy()

# %%
# List all of the columns
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'TCKR',
#        'sector', 'industry', 'country', 'growth_rate', 'target_median_price',
#        'target_mean_price', 'target_high_price'],
#       dtype='object')

# %%
# Drop qualitative columns
dataset_train = dataset_train.drop(labels=['sector', 'industry', 'country', 'growth_rate', 'target_median_price', 'target_mean_price', 'target_high_price'], axis=1)
dataset_train.head()
# Out:
#          Date    Open   High    Low  Close  Adj Close    Volume  TCKR
# 0  2019-12-19  11.000  11.96  10.50  10.70      10.70   89400.0  INDO
# 1  2019-12-20  10.808  12.49   9.25   9.65       9.65  503000.0  INDO
# 2  2019-12-23   8.790   8.79   7.25   7.81       7.81  117400.0  INDO
# 3  2019-12-24   7.500   7.64   6.00   6.41       6.41  102800.0  INDO
# 4  2019-12-26   6.420   7.72   6.42   7.41       7.41   78400.0  INDO

# %%
# Isolate just 1 TCKR to attempt LSTM process (train on 2019-2021 data)
INDO_dataset_train = dataset_train[(dataset_train.TCKR == 'INDO') & (dataset_train.Date < '2022-01-01')]
INDO_dataset_train
# Out:
#            Date    Open    High     Low   Close  Adj Close    Volume  TCKR
# 0    2019-12-19  11.000  11.960  10.500  10.700     10.700   89400.0  INDO
# 1    2019-12-20  10.808  12.490   9.250   9.650      9.650  503000.0  INDO
# 2    2019-12-23   8.790   8.790   7.250   7.810      7.810  117400.0  INDO
# 3    2019-12-24   7.500   7.640   6.000   6.410      6.410  102800.0  INDO
# 4    2019-12-26   6.420   7.720   6.420   7.410      7.410   78400.0  INDO
# ..          ...     ...     ...     ...     ...        ...       ...   ...
# 508  2021-12-27   2.960   2.979   2.955   2.979      2.979    3700.0  INDO
# 509  2021-12-28   3.000   3.010   2.950   2.950      2.950    7400.0  INDO
# 510  2021-12-29   2.950   2.950   2.800   2.800      2.800    8800.0  INDO
# 511  2021-12-30   2.838   2.838   2.730   2.797      2.797    5200.0  INDO
# 512  2021-12-31   2.800   2.900   2.700   2.800      2.800   12000.0  INDO
#
# [513 rows x 8 columns]

# %%
# Use the Open Stock Price Column to train the model
training_set = INDO_dataset_train.iloc[:,1:2].values

print(training_set)
print(training_set.shape)
# Out:
# [[11.        ]
#  [10.80799961]
#  [ 8.78999996]
#  [ 7.5       ]
#  [ 6.42000008]
#  [ 7.6500001 ]
#  [ 7.25      ]
#  [ 7.05000019]
#  [ 7.03000021]
#  [ 7.1500001 ]
#  [ 7.0999999 ]
#  [ 7.13000011]
#  [ 8.06999969]
#  [ 7.26000023]
#  [ 7.98999977]
#  [ 7.6500001 ]
#  [ 7.69999981]
#  [ 8.30000019]
#  [ 8.68999958]
#  [ 8.53999996]
#  [ 8.28999996]
#  [ 8.19999981]
#  [ 7.69999981]
#  [ 7.88999987]
#  [ 7.78000021]
#  [ 7.53999996]
#  [ 7.28999996]
#  [ 7.26999998]
#  [ 7.01000023]
#  [ 6.86999989]
#  [ 6.75      ]
#  [ 6.73999977]
#  [ 7.09000015]
#  [ 6.82499981]
#  [ 6.5       ]
#  [ 6.69000006]
#  [ 7.        ]
#  [ 7.0999999 ]
#  [ 7.30000019]
#  [ 7.3499999 ]
#  [ 6.90299988]
#  [ 7.01999998]
#  [ 6.73999977]
#  [ 6.63800001]
#  [ 6.76999998]
#  [ 6.57000017]
#  [ 6.56500006]
#  [ 5.71500015]
#  [ 5.25      ]
#  [ 5.        ]
#  [ 4.90999985]
#  [ 5.        ]
#  [ 4.99599981]
#  [ 4.42000008]
#  [ 4.20200014]
#  [ 3.18000007]
#  [ 2.78999996]
#  [ 2.68000007]
#  [ 2.3599999 ]
#  [ 1.66999996]
#  [ 1.54999995]
#  [ 1.54999995]
#  [ 1.99600005]
#  [ 1.59599996]
#  [ 2.74000001]
#  [ 4.75      ]
#  [ 4.15999985]
#  [ 3.52999997]
#  [ 3.99000001]
#  [ 3.62299991]
#  [ 3.52999997]
#  [ 3.54999995]
#  [ 3.29999995]
#  [ 3.68000007]
#  [ 3.55999994]
#  [ 3.5       ]
#  [ 3.70000005]
#  [ 3.5       ]
#  [ 3.5999999 ]
#  [ 3.99000001]
#  [ 3.6400001 ]
#  [ 3.5       ]
#  [ 3.5       ]
#  [ 3.5       ]
#  [ 3.95000005]
#  [ 4.        ]
#  [ 3.8499999 ]
#  [ 3.82999992]
#  [ 3.82999992]
#  [ 3.8599999 ]
#  [ 3.87899995]
#  [ 4.0999999 ]
#  [ 5.05999994]
#  [ 5.44000006]
#  [ 5.5999999 ]
#  [ 4.30000019]
#  [ 4.5       ]
#  [ 4.75      ]
#  [ 4.829     ]
#  [ 5.12799978]
#  [ 4.88999987]
#  [ 4.25      ]
#  [ 4.71000004]
#  [ 4.88000011]
#  [ 4.37099981]
#  [ 4.39799976]
#  [ 4.17999983]
#  [ 4.26999998]
#  [ 3.95000005]
#  [ 3.8499999 ]
#  [ 3.8499999 ]
#  [ 3.8499999 ]
#  [ 3.86999989]
#  [ 3.86999989]
#  [ 4.07800007]
#  [ 4.11999989]
#  [ 4.87400007]
#  [ 5.57000017]
#  [ 5.5       ]
#  [ 4.5       ]
#  [ 4.36000013]
#  [ 4.65999985]
#  [ 4.86000013]
#  [ 5.11000013]
#  [ 5.01499987]
#  [ 6.92000008]
#  [ 5.55999994]
#  [ 6.        ]
#  [ 5.34000015]
#  [ 5.46500015]
#  [ 5.30000019]
#  [ 5.38999987]
#  [ 5.        ]
#  [ 4.37200022]
#  [ 4.19000006]
#  [ 4.25      ]
#  [ 4.51000023]
#  [ 4.25      ]
#  [ 4.48000002]
#  [ 4.05999994]
#  [ 4.0999999 ]
#  [ 5.96000004]
#  [ 5.80000019]
#  [ 4.98999977]
#  [ 4.55000019]
#  [ 4.76999998]
#  [ 4.75      ]
#  [ 4.88399982]
#  [ 5.88000011]
#  [ 5.25      ]
#  [ 4.78000021]
#  [ 4.62799978]
#  [ 4.57000017]
#  [ 5.25      ]
#  [ 4.875     ]
#  [ 4.5       ]
#  [ 4.75      ]
#  [ 4.68499994]
#  [ 4.63999987]
#  [ 4.67500019]
#  [ 4.80000019]
#  [ 4.74100018]
#  [ 4.55000019]
#  [ 4.5999999 ]
#  [ 4.4000001 ]
#  [ 4.55000019]
#  [ 4.59299994]
#  [ 4.69999981]
#  [ 4.42500019]
#  [ 4.4000001 ]
#  [ 4.25      ]
#  [ 4.25099993]
#  [ 4.34899998]
#  [ 4.44999981]
#  [ 4.32000017]
#  [ 4.32000017]
#  [ 4.3130002 ]
#  [ 4.30499983]
#  [ 4.25      ]
#  [ 4.38500023]
#  [ 4.35300016]
#  [ 4.48000002]
#  [ 4.4000001 ]
#  [ 4.28999996]
#  [ 4.59000015]
#  [ 4.4000001 ]
#  [ 4.48500013]
#  [ 4.48500013]
#  [ 4.5999999 ]
#  [ 4.26000023]
#  [ 4.4380002 ]
#  [ 4.59000015]
#  [ 4.44999981]
#  [ 4.5999999 ]
#  [ 4.5999999 ]
#  [ 4.5       ]
#  [ 4.78999996]
#  [ 4.59000015]
#  [ 4.73000002]
#  [ 4.5       ]
#  [ 4.5       ]
#  [ 4.30000019]
#  [ 4.6500001 ]
#  [ 4.75      ]
#  [ 5.28499985]
#  [ 5.19999981]
#  [ 4.48000002]
#  [ 4.5       ]
#  [ 4.56599998]
#  [ 4.5999999 ]
#  [ 4.44999981]
#  [ 5.05999994]
#  [ 5.03999996]
#  [ 5.13000011]
#  [ 4.46000004]
#  [ 4.67999983]
#  [ 5.        ]
#  [ 4.30999994]
#  [ 4.44999981]
#  [ 4.44999981]
#  [ 4.40999985]
#  [ 4.40100002]
#  [ 4.30000019]
#  [ 4.44999981]
#  [ 4.44999981]
#  [ 4.69999981]
#  [ 5.        ]
#  [ 4.64499998]
#  [ 4.44000006]
#  [ 4.78200006]
#  [ 4.67799997]
#  [ 4.51499987]
#  [ 4.5999999 ]
#  [ 4.54199982]
#  [ 4.69999981]
#  [ 4.84000015]
#  [ 5.        ]
#  [ 4.75      ]
#  [ 4.94999981]
#  [ 4.55999994]
#  [ 4.5999999 ]
#  [ 4.5999999 ]
#  [ 4.57000017]
#  [ 4.65999985]
#  [ 4.45900011]
#  [ 4.48999977]
#  [ 4.60900021]
#  [ 4.32000017]
#  [ 4.53000021]
#  [ 4.21000004]
#  [ 4.21000004]
#  [ 4.17500019]
#  [ 4.25      ]
#  [ 4.05000019]
#  [ 3.95000005]
#  [ 3.72900009]
#  [ 3.88000011]
#  [ 3.97000003]
#  [ 3.98000002]
#  [ 9.93000031]
#  [ 6.3499999 ]
#  [ 6.57999992]
#  [ 6.01000023]
#  [ 6.48999977]
#  [ 5.94999981]
#  [ 6.07999992]
#  [ 5.8499999 ]
#  [ 5.98999977]
#  [ 6.        ]
#  [ 5.90999985]
#  [ 6.05999994]
#  [ 5.80999994]
#  [ 6.17000008]
#  [ 6.46000004]
#  [ 6.38999987]
#  [ 7.        ]
#  [ 6.86000013]
#  [ 6.36800003]
#  [ 6.61000013]
#  [ 6.03000021]
#  [ 6.36000013]
#  [ 6.32000017]
#  [ 6.59000015]
#  [ 6.3499999 ]
#  [ 6.68400002]
#  [ 6.57999992]
#  [ 7.25      ]
#  [ 7.46000004]
#  [ 7.28999996]
#  [ 6.94000006]
#  [ 7.03000021]
#  [ 7.61000013]
#  [ 7.7249999 ]
#  [ 7.98999977]
#  [ 7.61000013]
#  [ 8.71000004]
#  [ 8.13000011]
#  [ 8.92000008]
#  [ 7.76000023]
#  [ 8.34000015]
#  [ 8.43999958]
#  [ 8.23999977]
#  [ 8.35999966]
#  [ 8.5       ]
#  [ 7.92999983]
#  [ 7.96999979]
#  [ 7.92000008]
#  [ 7.88999987]
#  [ 7.98000002]
#  [ 8.        ]
#  [ 8.        ]
#  [ 8.        ]
#  [ 7.30000019]
#  [ 7.0999999 ]
#  [ 7.        ]
#  [ 6.80000019]
#  [ 6.73000002]
#  [ 6.51999998]
#  [ 6.46000004]
#  [ 6.23000002]
#  [ 6.05999994]
#  [ 6.26999998]
#  [ 6.30000019]
#  [ 6.26999998]
#  [ 6.4000001 ]
#  [ 6.17299986]
#  [ 7.03000021]
#  [ 6.11299992]
#  [ 6.26499987]
#  [ 6.5       ]
#  [ 5.94700003]
#  [ 6.23999977]
#  [ 5.94999981]
#  [ 5.51000023]
#  [ 5.5       ]
#  [ 5.48999977]
#  [ 5.80999994]
#  [ 5.41400003]
#  [ 5.73000002]
#  [ 5.49499989]
#  [ 5.63000011]
#  [ 5.40999985]
#  [ 5.28000021]
#  [ 5.        ]
#  [ 5.171     ]
#  [ 5.40199995]
#  [ 5.4000001 ]
#  [ 5.17999983]
#  [ 5.17000008]
#  [ 5.15999985]
#  [ 5.15999985]
#  [ 6.        ]
#  [ 4.90999985]
#  [ 5.3499999 ]
#  [ 5.55900002]
#  [ 5.67999983]
#  [ 5.23000002]
#  [ 5.27299976]
#  [ 5.25      ]
#  [ 5.25500011]
#  [ 5.3499999 ]
#  [ 5.31099987]
#  [ 5.27899981]
#  [ 5.46999979]
#  [ 5.71000004]
#  [ 5.82800007]
#  [ 5.30999994]
#  [ 5.28000021]
#  [ 5.36000013]
#  [ 5.57000017]
#  [ 5.6500001 ]
#  [ 5.62900019]
#  [ 5.67000008]
#  [ 5.51999998]
#  [ 5.66800022]
#  [ 6.07000017]
#  [ 5.71000004]
#  [ 5.6500001 ]
#  [ 5.82000017]
#  [ 5.67500019]
#  [ 5.84499979]
#  [ 5.58699989]
#  [ 6.09000015]
#  [ 5.94999981]
#  [ 5.90999985]
#  [ 6.25      ]
#  [ 6.0999999 ]
#  [ 5.92000008]
#  [ 5.80000019]
#  [ 5.30000019]
#  [ 5.4000001 ]
#  [ 5.61999989]
#  [ 5.23000002]
#  [ 5.67999983]
#  [ 5.68300009]
#  [ 5.36000013]
#  [ 5.30000019]
#  [ 5.4000001 ]
#  [ 5.28000021]
#  [ 5.4000001 ]
#  [ 5.36000013]
#  [ 5.        ]
#  [ 4.90500021]
#  [ 5.19500017]
#  [ 4.95599985]
#  [ 4.80000019]
#  [ 4.96000004]
#  [ 5.        ]
#  [ 5.75      ]
#  [ 5.48000002]
#  [ 5.30999994]
#  [ 5.0999999 ]
#  [ 5.1500001 ]
#  [ 5.05499983]
#  [ 5.        ]
#  [ 4.96199989]
#  [ 5.        ]
#  [ 4.9000001 ]
#  [ 4.9000001 ]
#  [ 5.32299995]
#  [ 5.15600014]
#  [ 4.96999979]
#  [ 5.06400013]
#  [ 5.18400002]
#  [ 5.        ]
#  [ 4.82200003]
#  [ 4.92999983]
#  [ 4.9000001 ]
#  [ 4.94000006]
#  [ 4.94000006]
#  [ 4.94000006]
#  [ 5.0999999 ]
#  [ 4.92999983]
#  [ 4.875     ]
#  [ 4.91200018]
#  [ 4.9000001 ]
#  [ 4.8499999 ]
#  [ 5.05999994]
#  [ 4.92500019]
#  [ 4.80000019]
#  [ 4.75      ]
#  [ 4.38999987]
#  [ 4.32999992]
#  [ 4.57999992]
#  [ 4.30000019]
#  [ 4.57999992]
#  [ 4.81500006]
#  [ 4.36999989]
#  [ 4.5170002 ]
#  [ 4.5250001 ]
#  [ 4.40999985]
#  [ 5.3499999 ]
#  [ 4.65999985]
#  [ 4.36999989]
#  [ 4.5       ]
#  [ 4.36800003]
#  [ 4.42000008]
#  [ 4.51999998]
#  [ 4.30999994]
#  [ 4.49100018]
#  [ 4.46000004]
#  [ 4.30000019]
#  [ 4.25      ]
#  [ 4.25      ]
#  [ 4.23500013]
#  [ 4.25      ]
#  [ 4.25      ]
#  [ 4.19000006]
#  [ 4.11999989]
#  [ 4.09000015]
#  [ 4.25      ]
#  [ 4.0999999 ]
#  [ 4.0999999 ]
#  [ 4.07999992]
#  [ 4.07999992]
#  [ 4.05000019]
#  [ 4.00099993]
#  [ 4.0250001 ]
#  [ 4.        ]
#  [ 3.83999991]
#  [ 3.91100001]
#  [ 4.        ]
#  [ 3.99000001]
#  [ 3.8499999 ]
#  [ 3.76999998]
#  [ 3.8599999 ]
#  [ 3.75999999]
#  [ 3.76799989]
#  [ 3.63000011]
#  [ 3.5999999 ]
#  [ 3.43899989]
#  [ 3.31999993]
#  [ 2.91000009]
#  [ 3.21000004]
#  [ 3.07500005]
#  [ 3.3499999 ]
#  [ 3.30999994]
#  [ 3.13199997]
#  [ 3.18000007]
#  [ 3.25      ]
#  [ 3.02999997]
#  [ 2.9000001 ]
#  [ 3.03999996]
#  [ 2.95000005]
#  [ 2.95000005]
#  [ 3.00999999]
#  [ 2.9749999 ]
#  [ 2.95000005]
#  [ 2.96000004]
#  [ 3.        ]
#  [ 2.95000005]
#  [ 2.83800006]
#  [ 2.79999995]]
# (513, 1)

# %%
# Normalizing the Dataset
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))
scaled_training_set = scaler.fit_transform(training_set)

scaled_training_set
# Out:
# array([[1.        ],
#        [0.9796825 ],
#        [0.76613756],
#        [0.62962963],
#        [0.51534393],
#        [0.64550266],
#        [0.60317461],
#        [0.5820106 ],
#        [0.5798942 ],
#        [0.5925926 ],
#        [0.58730158],
#        [0.5904762 ],
#        [0.68994706],
#        [0.60423283],
#        [0.68148146],
#        [0.64550266],
#        [0.65079363],
#        [0.71428574],
#        [0.75555551],
#        [0.73968254],
#        [0.71322751],
#        [0.70370369],
#        [0.65079363],
#        [0.67089946],
#        [0.65925928],
#        [0.63386243],
#        [0.60740741],
#        [0.60529101],
#        [0.5777778 ],
#        [0.56296295],
#        [0.55026455],
#        [0.54920633],
#        [0.5862434 ],
#        [0.55820104],
#        [0.52380953],
#        [0.54391535],
#        [0.57671958],
#        [0.58730158],
#        [0.60846563],
#        [0.61375661],
#        [0.56645502],
#        [0.57883598],
#        [0.54920633],
#        [0.5384127 ],
#        [0.55238095],
#        [0.53121695],
#        [0.53068784],
#        [0.44074076],
#        [0.39153439],
#        [0.36507937],
#        [0.35555554],
#        [0.36507937],
#        [0.36465607],
#        [0.30370372],
#        [0.28063494],
#        [0.17248678],
#        [0.13121693],
#        [0.11957673],
#        [0.08571428],
#        [0.01269841],
#        [0.        ],
#        [0.        ],
#        [0.04719578],
#        [0.00486773],
#        [0.12592593],
#        [0.33862434],
#        [0.27619046],
#        [0.20952381],
#        [0.25820106],
#        [0.21936507],
#        [0.20952381],
#        [0.21164021],
#        [0.18518518],
#        [0.22539684],
#        [0.21269841],
#        [0.20634921],
#        [0.22751324],
#        [0.20634921],
#        [0.21693121],
#        [0.25820106],
#        [0.22116404],
#        [0.20634921],
#        [0.20634921],
#        [0.20634921],
#        [0.25396826],
#        [0.25925926],
#        [0.24338624],
#        [0.24126984],
#        [0.24126984],
#        [0.24444444],
#        [0.24645502],
#        [0.26984126],
#        [0.37142857],
#        [0.41164022],
#        [0.42857142],
#        [0.29100531],
#        [0.31216932],
#        [0.33862434],
#        [0.34698413],
#        [0.37862432],
#        [0.35343914],
#        [0.28571429],
#        [0.33439154],
#        [0.35238097],
#        [0.2985185 ],
#        [0.30137564],
#        [0.27830686],
#        [0.28783069],
#        [0.25396826],
#        [0.24338624],
#        [0.24338624],
#        [0.24338624],
#        [0.24550264],
#        [0.24550264],
#        [0.26751324],
#        [0.27195766],
#        [0.35174604],
#        [0.42539685],
#        [0.41798942],
#        [0.31216932],
#        [0.29735452],
#        [0.32910052],
#        [0.35026457],
#        [0.37671959],
#        [0.36666666],
#        [0.56825398],
#        [0.42433862],
#        [0.47089947],
#        [0.40105822],
#        [0.41428573],
#        [0.39682542],
#        [0.4063492 ],
#        [0.36507937],
#        [0.29862437],
#        [0.27936509],
#        [0.28571429],
#        [0.31322754],
#        [0.28571429],
#        [0.31005292],
#        [0.26560846],
#        [0.26984126],
#        [0.46666667],
#        [0.44973547],
#        [0.36402114],
#        [0.31746034],
#        [0.34074074],
#        [0.33862434],
#        [0.35280422],
#        [0.45820107],
#        [0.39153439],
#        [0.34179897],
#        [0.32571427],
#        [0.31957674],
#        [0.39153439],
#        [0.35185186],
#        [0.31216932],
#        [0.33862434],
#        [0.33174603],
#        [0.32698412],
#        [0.33068785],
#        [0.34391537],
#        [0.33767198],
#        [0.31746034],
#        [0.32275132],
#        [0.30158732],
#        [0.31746034],
#        [0.32201058],
#        [0.33333332],
#        [0.30423283],
#        [0.30158732],
#        [0.28571429],
#        [0.2858201 ],
#        [0.29619048],
#        [0.30687829],
#        [0.29312171],
#        [0.29312171],
#        [0.29238098],
#        [0.29153438],
#        [0.28571429],
#        [0.30000003],
#        [0.29661378],
#        [0.31005292],
#        [0.30158732],
#        [0.28994709],
#        [0.32169314],
#        [0.30158732],
#        [0.31058203],
#        [0.31058203],
#        [0.32275132],
#        [0.28677251],
#        [0.30560849],
#        [0.32169314],
#        [0.30687829],
#        [0.32275132],
#        [0.32275132],
#        [0.31216932],
#        [0.34285714],
#        [0.32169314],
#        [0.33650794],
#        [0.31216932],
#        [0.31216932],
#        [0.29100531],
#        [0.32804234],
#        [0.33862434],
#        [0.39523808],
#        [0.38624337],
#        [0.31005292],
#        [0.31216932],
#        [0.31915344],
#        [0.32275132],
#        [0.30687829],
#        [0.37142857],
#        [0.36931217],
#        [0.37883599],
#        [0.30793652],
#        [0.33121692],
#        [0.36507937],
#        [0.29206349],
#        [0.30687829],
#        [0.30687829],
#        [0.30264549],
#        [0.30169313],
#        [0.29100531],
#        [0.30687829],
#        [0.30687829],
#        [0.33333332],
#        [0.36507937],
#        [0.32751323],
#        [0.30582012],
#        [0.34201059],
#        [0.33100529],
#        [0.3137566 ],
#        [0.32275132],
#        [0.31661374],
#        [0.33333332],
#        [0.34814817],
#        [0.36507937],
#        [0.33862434],
#        [0.35978834],
#        [0.31851852],
#        [0.32275132],
#        [0.32275132],
#        [0.31957674],
#        [0.32910052],
#        [0.3078307 ],
#        [0.31111109],
#        [0.32370373],
#        [0.29312171],
#        [0.31534394],
#        [0.28148149],
#        [0.28148149],
#        [0.2777778 ],
#        [0.28571429],
#        [0.26455029],
#        [0.25396826],
#        [0.23058202],
#        [0.24656086],
#        [0.25608466],
#        [0.25714286],
#        [0.88677252],
#        [0.5079365 ],
#        [0.53227513],
#        [0.4719577 ],
#        [0.5227513 ],
#        [0.46560845],
#        [0.47936507],
#        [0.45502645],
#        [0.46984125],
#        [0.47089947],
#        [0.46137565],
#        [0.47724867],
#        [0.45079365],
#        [0.4888889 ],
#        [0.51957673],
#        [0.5121693 ],
#        [0.57671958],
#        [0.56190478],
#        [0.50984128],
#        [0.53544975],
#        [0.4740741 ],
#        [0.50899473],
#        [0.50476193],
#        [0.53333335],
#        [0.5079365 ],
#        [0.54328043],
#        [0.53227513],
#        [0.60317461],
#        [0.62539683],
#        [0.60740741],
#        [0.57037038],
#        [0.5798942 ],
#        [0.64126986],
#        [0.65343915],
#        [0.68148146],
#        [0.64126986],
#        [0.75767196],
#        [0.69629631],
#        [0.77989419],
#        [0.65714288],
#        [0.71851854],
#        [0.72910049],
#        [0.70793649],
#        [0.72063489],
#        [0.73544974],
#        [0.67513226],
#        [0.67936506],
#        [0.67407408],
#        [0.67089946],
#        [0.68042328],
#        [0.68253968],
#        [0.68253968],
#        [0.68253968],
#        [0.60846563],
#        [0.58730158],
#        [0.57671958],
#        [0.55555558],
#        [0.54814815],
#        [0.52592593],
#        [0.51957673],
#        [0.4952381 ],
#        [0.47724867],
#        [0.4994709 ],
#        [0.50264553],
#        [0.4994709 ],
#        [0.51322753],
#        [0.48920634],
#        [0.5798942 ],
#        [0.48285714],
#        [0.49894179],
#        [0.52380953],
#        [0.46529101],
#        [0.49629627],
#        [0.46560845],
#        [0.41904765],
#        [0.41798942],
#        [0.4169312 ],
#        [0.45079365],
#        [0.4088889 ],
#        [0.44232805],
#        [0.41746031],
#        [0.43174605],
#        [0.4084656 ],
#        [0.39470902],
#        [0.36507937],
#        [0.38317461],
#        [0.40761905],
#        [0.40740742],
#        [0.38412697],
#        [0.38306879],
#        [0.38201057],
#        [0.38201057],
#        [0.47089947],
#        [0.35555554],
#        [0.4021164 ],
#        [0.42423281],
#        [0.43703702],
#        [0.38941799],
#        [0.39396823],
#        [0.39153439],
#        [0.39206351],
#        [0.4021164 ],
#        [0.39798941],
#        [0.39460316],
#        [0.4148148 ],
#        [0.44021165],
#        [0.45269842],
#        [0.39788359],
#        [0.39470902],
#        [0.40317462],
#        [0.42539685],
#        [0.43386245],
#        [0.43164023],
#        [0.43597885],
#        [0.42010582],
#        [0.43576722],
#        [0.4783069 ],
#        [0.44021165],
#        [0.43386245],
#        [0.45185187],
#        [0.43650796],
#        [0.45449734],
#        [0.42719576],
#        [0.4804233 ],
#        [0.46560845],
#        [0.46137565],
#        [0.4973545 ],
#        [0.48148147],
#        [0.46243387],
#        [0.44973547],
#        [0.39682542],
#        [0.40740742],
#        [0.43068782],
#        [0.38941799],
#        [0.43703702],
#        [0.43735451],
#        [0.40317462],
#        [0.39682542],
#        [0.40740742],
#        [0.39470902],
#        [0.40740742],
#        [0.40317462],
#        [0.36507937],
#        [0.35502648],
#        [0.38571431],
#        [0.36042327],
#        [0.34391537],
#        [0.36084657],
#        [0.36507937],
#        [0.44444445],
#        [0.41587302],
#        [0.39788359],
#        [0.37566137],
#        [0.38095239],
#        [0.37089946],
#        [0.36507937],
#        [0.36105819],
#        [0.36507937],
#        [0.35449737],
#        [0.35449737],
#        [0.39925926],
#        [0.38158732],
#        [0.36190474],
#        [0.37185187],
#        [0.38455027],
#        [0.36507937],
#        [0.34624339],
#        [0.35767194],
#        [0.35449737],
#        [0.35873017],
#        [0.35873017],
#        [0.35873017],
#        [0.37566137],
#        [0.35767194],
#        [0.35185186],
#        [0.35576722],
#        [0.35449737],
#        [0.34920634],
#        [0.37142857],
#        [0.35714288],
#        [0.34391537],
#        [0.33862434],
#        [0.30052909],
#        [0.29417989],
#        [0.32063492],
#        [0.29100531],
#        [0.32063492],
#        [0.34550265],
#        [0.29841269],
#        [0.31396828],
#        [0.31481483],
#        [0.30264549],
#        [0.4021164 ],
#        [0.32910052],
#        [0.29841269],
#        [0.31216932],
#        [0.29820106],
#        [0.30370372],
#        [0.31428572],
#        [0.29206349],
#        [0.31121695],
#        [0.30793652],
#        [0.29100531],
#        [0.28571429],
#        [0.28571429],
#        [0.284127  ],
#        [0.28571429],
#        [0.28571429],
#        [0.27936509],
#        [0.27195766],
#        [0.26878309],
#        [0.28571429],
#        [0.26984126],
#        [0.26984126],
#        [0.26772486],
#        [0.26772486],
#        [0.26455029],
#        [0.25936508],
#        [0.26190478],
#        [0.25925926],
#        [0.24232804],
#        [0.24984128],
#        [0.25925926],
#        [0.25820106],
#        [0.24338624],
#        [0.23492064],
#        [0.24444444],
#        [0.23386244],
#        [0.23470899],
#        [0.22010584],
#        [0.21693121],
#        [0.19989417],
#        [0.18730158],
#        [0.14391536],
#        [0.17566138],
#        [0.16137567],
#        [0.19047618],
#        [0.18624338],
#        [0.16740741],
#        [0.17248678],
#        [0.17989418],
#        [0.15661376],
#        [0.14285716],
#        [0.15767196],
#        [0.14814816],
#        [0.14814816],
#        [0.15449736],
#        [0.15079364],
#        [0.14814816],
#        [0.14920636],
#        [0.15343916],
#        [0.14814816],
#        [0.13629631],
#        [0.13227513]])

# %%
scaled_training_set.size
# Out:
# 513

# %%
scaled_training_set[0:20, 0]
# Out:
# array([1.        , 0.9796825 , 0.76613756, 0.62962963, 0.51534393,
#        0.64550266, 0.60317461, 0.5820106 , 0.5798942 , 0.5925926 ,
#        0.58730158, 0.5904762 , 0.68994706, 0.60423283, 0.68148146,
#        0.64550266, 0.65079363, 0.71428574, 0.75555551, 0.73968254])

# %%
scaled_training_set.size*0.05
# Out:
# 25.650000000000002

# %%
# Define what X and y are
X_train = []
y_train = []
for i in range(60,scaled_training_set.size):
    X_train.append(scaled_training_set[i-60:i, 0])
    y_train.append(scaled_training_set[i, 0])
X_train = np.array(X_train)
y_train = np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (453, 60)
# (453,)

# %%
# Reshape the data
X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (453, 60, 1)

# %%
# Import libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Build the model and add layers to LSTM
regressor = Sequential()

regressor.add(LSTM(units=50, return_sequences=True, input_shape= (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1))

regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 60, 50)            20200
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the model
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 22s 166ms/step - loss: 0.0496
# Epoch 2/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.0144
# Epoch 3/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.0092
# Epoch 4/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0090
# Epoch 5/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0090
# Epoch 6/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0084
# Epoch 7/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0074
# Epoch 8/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0068
# Epoch 9/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.0068
# Epoch 10/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0072
# Epoch 11/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0062
# Epoch 12/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0057
# Epoch 13/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0063
# Epoch 14/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0067
# Epoch 15/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0063
# Epoch 16/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0062
# Epoch 17/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0057
# Epoch 18/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0060
# Epoch 19/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0080
# Epoch 20/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0067
# Epoch 21/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0054
# Epoch 22/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0058
# Epoch 23/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0057
# Epoch 24/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.0059
# Epoch 25/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0055
# Epoch 26/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0052
# Epoch 27/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.0053
# Epoch 28/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0057
# Epoch 29/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.0050
# Epoch 30/100
# 15/15 [==============================] - 2s 161ms/step - loss: 0.0054
# Epoch 31/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0053
# Epoch 32/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0055
# Epoch 33/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0056
# Epoch 34/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0050
# Epoch 35/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0055
# Epoch 36/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0048
# Epoch 37/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0051
# Epoch 38/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0049
# Epoch 39/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0048
# Epoch 40/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0046
# Epoch 41/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0050
# Epoch 42/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0047
# Epoch 43/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0046
# Epoch 44/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.0051
# Epoch 45/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0044
# Epoch 46/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0045
# Epoch 47/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0049
# Epoch 48/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0043
# Epoch 49/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0042
# Epoch 50/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0044
# Epoch 51/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0044
# Epoch 52/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0043
# Epoch 53/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0042
# Epoch 54/100
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0042
# Epoch 55/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0044
# Epoch 56/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0046
# Epoch 57/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0040
# Epoch 58/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0043
# Epoch 59/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0045
# Epoch 60/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0046
# Epoch 61/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.0054
# Epoch 62/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0043
# Epoch 63/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0038
# Epoch 64/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0038
# Epoch 65/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0038
# Epoch 66/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0041
# Epoch 67/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0040
# Epoch 68/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0039
# Epoch 69/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0047
# Epoch 70/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0042
# Epoch 71/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0039
# Epoch 72/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0038
# Epoch 73/100
# 15/15 [==============================] - 2s 161ms/step - loss: 0.0047
# Epoch 74/100
# 15/15 [==============================] - 2s 120ms/step - loss: 0.0042
# Epoch 75/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.0040
# Epoch 76/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0039
# Epoch 77/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0038
# Epoch 78/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.0038
# Epoch 79/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.0041
# Epoch 80/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0043
# Epoch 81/100
# 15/15 [==============================] - 2s 95ms/step - loss: 0.0037
# Epoch 82/100
# 15/15 [==============================] - 1s 97ms/step - loss: 0.0038
# Epoch 83/100
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0035
# Epoch 84/100
# 15/15 [==============================] - 2s 132ms/step - loss: 0.0038
# Epoch 85/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.0035
# Epoch 86/100
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0036
# Epoch 87/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0037
# Epoch 88/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.0037
# Epoch 89/100
# 15/15 [==============================] - 2s 156ms/step - loss: 0.0035
# Epoch 90/100
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0032
# Epoch 91/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.0037
# Epoch 92/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0034
# Epoch 93/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0037
# Epoch 94/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.0036
# Epoch 95/100
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0036
# Epoch 96/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.0034
# Epoch 97/100
# 15/15 [==============================] - 2s 164ms/step - loss: 0.0035
# Epoch 98/100
# 15/15 [==============================] - 2s 167ms/step - loss: 0.0032
# Epoch 99/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.0035
# Epoch 100/100
# 15/15 [==============================] - 3s 168ms/step - loss: 0.0033

# %%
# Use 2022 data as testing set
INDO_dataset_test = dataset_train[(dataset_train.TCKR == 'INDO') & (dataset_train.Date >= '2022-01-01')]
INDO_dataset_test
# Out:
#            Date   Open  High    Low  Close  Adj Close    Volume  TCKR
# 513  2022-01-03  2.838  2.85  2.720  2.846      2.846    2500.0  INDO
# 514  2022-01-04  2.850  3.45  2.720  2.900      2.900  139200.0  INDO
# 515  2022-01-05  2.900  2.95  2.770  2.770      2.770    6500.0  INDO
# 516  2022-01-06  2.630  2.95  2.630  2.850      2.850    2000.0  INDO
# 517  2022-01-07  2.720  2.80  2.677  2.750      2.750    7200.0  INDO
# ..          ...    ...   ...    ...    ...        ...       ...   ...
# 721  2022-10-31  6.370  6.72  6.340  6.670      6.670  319600.0  INDO
# 722  2022-11-01  6.900  7.05  6.660  6.750      6.750  374500.0  INDO
# 723  2022-11-02  6.720  6.88  6.410  6.610      6.610  605100.0  INDO
# 724  2022-11-03  6.560  6.82  6.542  6.700      6.700  177700.0  INDO
# 725  2022-11-04  7.120  7.28  6.640  6.990      6.990  567372.0  INDO
#
# [213 rows x 8 columns]

# %%
# Extract the testing stock prices
dataset_test = INDO_dataset_test.iloc[:,1:2].values
dataset_test
# Out:
# array([[ 2.83800006],
#        [ 2.8499999 ],
#        [ 2.9000001 ],
#        [ 2.63000011],
#        [ 2.72000003],
#        [ 2.71000004],
#        [ 2.6500001 ],
#        [ 2.96000004],
#        [ 3.16000009],
#        [ 3.11800003],
#        [ 3.27999997],
#        [ 4.25      ],
#        [ 3.66000009],
#        [ 3.6500001 ],
#        [ 3.42000008],
#        [ 3.6500001 ],
#        [ 3.41000009],
#        [ 3.0999999 ],
#        [ 6.17000008],
#        [ 5.01000023],
#        [ 4.61999989],
#        [ 4.0999999 ],
#        [ 3.81999993],
#        [ 4.03000021],
#        [ 4.63000011],
#        [ 4.23000002],
#        [ 4.23999977],
#        [ 4.5999999 ],
#        [ 4.5       ],
#        [ 4.71999979],
#        [ 4.84000015],
#        [ 4.57999992],
#        [ 4.44999981],
#        [ 4.57999992],
#        [ 4.90999985],
#        [ 7.96999979],
#        [14.10000038],
#        [10.        ],
#        [14.40999985],
#        [12.55000019],
#        [12.71000004],
#        [22.25      ],
#        [22.19000053],
#        [46.70000076],
#        [73.91000366],
#        [30.38999939],
#        [44.04999924],
#        [37.5       ],
#        [25.37999916],
#        [23.78000069],
#        [25.63999939],
#        [30.79999924],
#        [35.00999832],
#        [33.29000092],
#        [28.68000031],
#        [29.10000038],
#        [26.40999985],
#        [23.86000061],
#        [21.02000046],
#        [20.53000069],
#        [23.04999924],
#        [23.5       ],
#        [21.96999931],
#        [21.56999969],
#        [21.98999977],
#        [20.89999962],
#        [19.67000008],
#        [19.65999985],
#        [18.85000038],
#        [16.43000031],
#        [15.59000015],
#        [15.18000031],
#        [23.20000076],
#        [23.54999924],
#        [23.54999924],
#        [23.79999924],
#        [19.25499916],
#        [17.79999924],
#        [19.11000061],
#        [18.61000061],
#        [17.79999924],
#        [19.89999962],
#        [17.44000053],
#        [17.22999954],
#        [19.68000031],
#        [20.38999939],
#        [18.65999985],
#        [17.02000046],
#        [14.75      ],
#        [13.82999992],
#        [12.86999989],
#        [13.39999962],
#        [13.56999969],
#        [18.        ],
#        [17.20000076],
#        [14.97000027],
#        [16.20999908],
#        [15.09000015],
#        [14.63000011],
#        [14.52000046],
#        [14.51000023],
#        [14.81999969],
#        [18.        ],
#        [16.75      ],
#        [15.        ],
#        [15.26000023],
#        [14.02999973],
#        [12.11999989],
#        [12.60000038],
#        [11.5       ],
#        [ 9.60000038],
#        [ 8.13000011],
#        [ 9.56999969],
#        [ 7.86000013],
#        [ 7.44999981],
#        [ 8.05000019],
#        [ 7.9000001 ],
#        [ 7.26999998],
#        [ 7.07999992],
#        [ 6.92000008],
#        [ 7.48999977],
#        [ 8.        ],
#        [ 7.44000006],
#        [ 6.69000006],
#        [ 6.51000023],
#        [ 6.11000013],
#        [ 5.88000011],
#        [ 6.19999981],
#        [ 6.44000006],
#        [ 6.1500001 ],
#        [ 7.76000023],
#        [ 6.26999998],
#        [ 6.55999994],
#        [ 6.94999981],
#        [ 6.67000008],
#        [ 6.51000023],
#        [ 6.92999983],
#        [ 6.61999989],
#        [ 6.36999989],
#        [ 5.8499999 ],
#        [ 6.13999987],
#        [ 6.        ],
#        [ 6.15999985],
#        [ 6.05000019],
#        [ 6.23999977],
#        [ 6.13999987],
#        [ 6.34000015],
#        [ 6.05000019],
#        [ 5.80000019],
#        [ 5.94000006],
#        [ 6.        ],
#        [ 5.8499999 ],
#        [ 6.03000021],
#        [ 6.17000008],
#        [ 6.        ],
#        [ 5.94999981],
#        [ 6.03999996],
#        [ 5.98000002],
#        [ 7.15999985],
#        [ 7.01999998],
#        [ 8.77000046],
#        [10.61999989],
#        [11.18000031],
#        [ 8.96000004],
#        [10.11999989],
#        [ 8.72000027],
#        [ 7.57999992],
#        [ 7.21999979],
#        [ 7.34000015],
#        [ 7.94999981],
#        [ 7.5       ],
#        [ 7.26999998],
#        [ 7.65999985],
#        [ 7.5       ],
#        [ 7.23000002],
#        [ 6.96999979],
#        [ 7.32000017],
#        [ 7.01000023],
#        [ 6.57000017],
#        [ 6.21000004],
#        [ 6.36999989],
#        [ 6.25      ],
#        [ 5.71999979],
#        [ 5.5999999 ],
#        [ 5.36000013],
#        [ 5.48999977],
#        [ 6.34000015],
#        [ 6.76000023],
#        [ 6.88000011],
#        [ 7.17999983],
#        [ 8.30000019],
#        [ 8.22000027],
#        [ 7.69000006],
#        [ 7.75      ],
#        [ 6.71000004],
#        [ 6.25      ],
#        [ 6.03000021],
#        [ 6.84000015],
#        [ 6.63000011],
#        [ 6.5999999 ],
#        [ 6.36999989],
#        [ 7.25      ],
#        [ 6.55000019],
#        [ 6.55000019],
#        [ 6.5       ],
#        [ 7.21999979],
#        [ 7.19999981],
#        [ 6.69999981],
#        [ 6.36999989],
#        [ 6.9000001 ],
#        [ 6.71999979],
#        [ 6.55999994],
#        [ 7.11999989]])

# %%
dataset_test.size
# Out:
# 213

# %%
# Preparing the Input for the Model

dataset_total = pd.concat((INDO_dataset_train['Open'], INDO_dataset_test['Open']), axis=0)

inputs = dataset_total[len(dataset_total)- len(dataset_test)-60:].values

inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(60,dataset_test.size):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1], 1))

print(X_test.shape)
# Out:
# (153, 60, 1)

# %%
# Predicting the 2022 Stock Prices
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 5/5 [==============================] - 4s 59ms/step

# %%
# Plotting the Actual and Predicted Prices
plt.plot(dataset_test, color='red', label='Actual Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('INDO Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('INDO Stock Price')
plt.legend()
