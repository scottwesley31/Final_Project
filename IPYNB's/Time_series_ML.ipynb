# %%
# !pip install --pre pycaret

# %%
# !gdown --id 1cijWpm7_S80zrRUJsBhTFk9btQYXuRHv
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1cijWpm7_S80zrRUJsBhTFk9btQYXuRHv
# To: /content/launchit.csv
# 100% 53.0M/53.0M [00:00<00:00, 161MB/s]

# %%
# read the csv file
import pandas as pd

data = pd.read_csv('launchit.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date    Open   High    Low  Close  Adj Close    Volume  TCKR  sector  \
# 0 2019-12-19  11.000  11.96  10.50  10.70      10.70   89400.0  INDO  Energy
# 1 2019-12-20  10.808  12.49   9.25   9.65       9.65  503000.0  INDO  Energy
# 2 2019-12-23   8.790   8.79   7.25   7.81       7.81  117400.0  INDO  Energy
# 3 2019-12-24   7.500   7.64   6.00   6.41       6.41  102800.0  INDO  Energy
# 4 2019-12-26   6.420   7.72   6.42   7.41       7.41   78400.0  INDO  Energy
#
#         industry    country  growth_rate  target_median_price  \
# 0  Oil & Gas E&P  Indonesia        1.206                 15.0
# 1  Oil & Gas E&P  Indonesia        1.206                 15.0
# 2  Oil & Gas E&P  Indonesia        1.206                 15.0
# 3  Oil & Gas E&P  Indonesia        1.206                 15.0
# 4  Oil & Gas E&P  Indonesia        1.206                 15.0
#
#    target_mean_price  target_high_price
# 0               15.0               15.0
# 1               15.0               15.0
# 2               15.0               15.0
# 3               15.0               15.0
# 4               15.0               15.0

# %%
data.dtypes
# Out:
# Date                   datetime64[ns]
# Open                          float64
# High                          float64
# Low                           float64
# Close                         float64
# Adj Close                     float64
# Volume                        float64
# TCKR                           object
# sector                         object
# industry                       object
# country                        object
# growth_rate                   float64
# target_median_price           float64
# target_mean_price             float64
# target_high_price             float64
# dtype: object

# %%
# data['industry'] = pd.to_numeric(data['industry'],errors = 'coerce')

# Label Encode non-numeric columns
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['industry'] = le.fit_transform(data['industry'])

# %%
data.dtypes
# Out:
# Date                   datetime64[ns]
# High                          float64
# Low                           float64
# Close                         float64
# Adj Close                     float64
# Volume                        float64
# sector                         object
# industry                        int64
# country                        object
# growth_rate                   float64
# target_median_price           float64
# target_mean_price             float64
# target_high_price             float64
# time_series                    object
# dtype: object

# %%
data.head()
# Out:
#         Date    Open   High    Low  Close  Adj Close    Volume  TCKR  sector  \
# 0 2019-12-19  11.000  11.96  10.50  10.70      10.70   89400.0  INDO  Energy
# 1 2019-12-20  10.808  12.49   9.25   9.65       9.65  503000.0  INDO  Energy
# 2 2019-12-23   8.790   8.79   7.25   7.81       7.81  117400.0  INDO  Energy
# 3 2019-12-24   7.500   7.64   6.00   6.41       6.41  102800.0  INDO  Energy
# 4 2019-12-26   6.420   7.72   6.42   7.41       7.41   78400.0  INDO  Energy
#
#    industry    country  growth_rate  target_median_price  target_mean_price  \
# 0        59  Indonesia        1.206                 15.0               15.0
# 1        59  Indonesia        1.206                 15.0               15.0
# 2        59  Indonesia        1.206                 15.0               15.0
# 3        59  Indonesia        1.206                 15.0               15.0
# 4        59  Indonesia        1.206                 15.0               15.0
#
#    target_high_price
# 0               15.0
# 1               15.0
# 2               15.0
# 3               15.0
# 4               15.0

# %%
# combine TCKR and ADj Close column as time_series
data['TCKR'] = ['TCKR_' + str(i) for i in data['TCKR']]
data['Open'] = ['Open_' + str(i) for i in data['Open']]
data['time_series'] = data[['TCKR', 'Open']].apply(lambda x: '_'.join(x), axis=1)
data.drop(['TCKR', 'Open'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TCKR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-50109c3caad9> in <module>
#       1 # combine TCKR and ADj Close column as time_series
# ----> 2 data['TCKR'] = ['TCKR_' + str(i) for i in data['TCKR']]
#       3 data['Open'] = ['Open_' + str(i) for i in data['Open']]
#       4 data['time_series'] = data[['TCKR', 'Open']].apply(lambda x: '_'.join(x), axis=1)
#       5 data.drop(['TCKR', 'Open'], axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'TCKR'

# %%
data.head()
# Out:
#         Date   High    Low  Close  Adj Close    Volume  sector  industry  \
# 0 2019-12-19  11.96  10.50  10.70      10.70   89400.0  Energy        59
# 1 2019-12-20  12.49   9.25   9.65       9.65  503000.0  Energy        59
# 2 2019-12-23   8.79   7.25   7.81       7.81  117400.0  Energy        59
# 3 2019-12-24   7.64   6.00   6.41       6.41  102800.0  Energy        59
# 4 2019-12-26   7.72   6.42   7.41       7.41   78400.0  Energy        59
#
#      country  growth_rate  target_median_price  target_mean_price  \
# 0  Indonesia        1.206                 15.0               15.0
# 1  Indonesia        1.206                 15.0               15.0
# 2  Indonesia        1.206                 15.0               15.0
# 3  Indonesia        1.206                 15.0               15.0
# 4  Indonesia        1.206                 15.0               15.0
#
#    target_high_price                       time_series
# 0               15.0               TCKR_INDO_Open_11.0
# 1               15.0  TCKR_INDO_Open_10.80799961090088
# 2               15.0  TCKR_INDO_Open_8.789999961853027
# 3               15.0                TCKR_INDO_Open_7.5
# 4               15.0  TCKR_INDO_Open_6.420000076293945

# %%
data.dtypes
# Out:
# Date                   datetime64[ns]
# Open                          float64
# High                          float64
# Low                           float64
# Close                         float64
# Adj Close                     float64
# Volume                        float64
# sector                         object
# country                        object
# growth_rate                   float64
# target_median_price           float64
# target_mean_price             float64
# target_high_price             float64
# time_series                    object
# dtype: object

# %%
# extract features from date
data['month'] = [i.month for i in data['Date']]
data['year'] = [i.year for i in data['Date']]
data['day_of_week'] = [i.dayofweek for i in data['Date']]
data['day_of_year'] = [i.dayofyear for i in data['Date']]
data.head()
# Out:
#         Date    Open   High    Low  Close  Adj Close    Volume  sector  \
# 0 2019-12-19  11.000  11.96  10.50  10.70      10.70   89400.0  Energy
# 1 2019-12-20  10.808  12.49   9.25   9.65       9.65  503000.0  Energy
# 2 2019-12-23   8.790   8.79   7.25   7.81       7.81  117400.0  Energy
# 3 2019-12-24   7.500   7.64   6.00   6.41       6.41  102800.0  Energy
# 4 2019-12-26   6.420   7.72   6.42   7.41       7.41   78400.0  Energy
#
#      country  growth_rate  target_median_price  target_mean_price  \
# 0  Indonesia        1.206                 15.0               15.0
# 1  Indonesia        1.206                 15.0               15.0
# 2  Indonesia        1.206                 15.0               15.0
# 3  Indonesia        1.206                 15.0               15.0
# 4  Indonesia        1.206                 15.0               15.0
#
#    target_high_price            time_series  month  year  day_of_week  \
# 0               15.0  TCKR_INDO_industry_59     12  2019            3
# 1               15.0  TCKR_INDO_industry_59     12  2019            4
# 2               15.0  TCKR_INDO_industry_59     12  2019            0
# 3               15.0  TCKR_INDO_industry_59     12  2019            1
# 4               15.0  TCKR_INDO_industry_59     12  2019            3
#
#    day_of_year
# 0          353
# 1          354
# 2          357
# 3          358
# 4          360

# %%
# check the unique time_series
data['time_series'].nunique()
# Out:
# 547

# %%
# plot multiple time series with moving avgs in a loop
import plotly.express as px
for i in data['time_series'].unique():
    subset = data[data['time_series'] == i]
    subset['moving_average'] = subset['Adj Close'].rolling(30).mean()
    fig = px.line(subset, x="Date", y=["Adj Close","moving_average"], title = i, template = 'plotly_dark')
    fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
