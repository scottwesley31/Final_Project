# %%
# !pip install --pre pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 487 kB 9.0 MB/s
# ...
#      |████████████████████████████████| 106 kB 38.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 46.0 MB/s
# ...
#      |████████████████████████████████| 72 kB 996 kB/s
# ...
#      |████████████████████████████████| 62 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 7.0 MB 51.3 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 280 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 79.9 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 141 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 35.7 MB/s
# ...
#      |████████████████████████████████| 44 kB 3.1 MB/s
#   Installing build dependencies ... done
# ...

# %%
# !gdown --id 1-GEvvmRpDdmTottFaSLEr-p-GlM6JsOK
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1-GEvvmRpDdmTottFaSLEr-p-GlM6JsOK
# To: /content/launchit_info.csv
# 100% 115k/115k [00:00<00:00, 58.8MB/s]

# %%
# Import dependencies
from pycaret.regression import *
# from pycaret.classification import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('launchit_info.csv')
df.head()
# Out:
#    Unnamed: 0   TCKR           sector              industry        country  \
# 0           0  MKDTY  Basic Materials             Chemicals          China
# 1           1   INDO           Energy         Oil & Gas E&P      Indonesia
# 2           2   MNPR       Healthcare         Biotechnology  United States
# 3           3   OCFT       Technology  Software—Application          China
# 4           4    SPT       Technology  Software—Application  United States
#
#    growth_rate  debtToEquity  currentRatio    forwardPE
# 0       -0.671           NaN         0.928    -0.002444
# 1        1.206        12.272         2.707    -9.695652
# 2          NaN         0.167         7.508    -2.596638
# 3        0.004         9.305         1.241    -3.550454
# 4        0.330        16.084         1.886 -3289.500000

# %%
# Check Data Types for all columns
df.dtypes
# Out:
# Unnamed: 0        int64
# TCKR             object
# sector           object
# industry         object
# country          object
# growth_rate     float64
# debtToEquity    float64
# currentRatio    float64
# forwardPE       float64
# dtype: object

# %%
# Calculate the correlation
df.corr()
# Out:
#               Unnamed: 0  growth_rate  debtToEquity  currentRatio  forwardPE
# Unnamed: 0      1.000000    -0.002417      0.018162      0.014292   0.020174
# growth_rate    -0.002417     1.000000     -0.010919      0.019141  -0.005796
# debtToEquity    0.018162    -0.010919      1.000000     -0.095880  -0.016143
# currentRatio    0.014292     0.019141     -0.095880      1.000000  -0.027934
# forwardPE       0.020174    -0.005796     -0.016143     -0.027934   1.000000

# %%
# Create Correlation matrix based on target variable: In this case "growth_rate", "Volume" or "currentRatio"
corr_matrix = df.corr().round(3)
print(corr_matrix["growth_rate"].sort_values(ascending=False))
# Out:
# growth_rate     1.000
# currentRatio    0.019
# Unnamed: 0     -0.002
# forwardPE      -0.006
# debtToEquity   -0.011
# Name: growth_rate, dtype: float64
