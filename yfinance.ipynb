# %%
# Import dependencies
# Note: you must pip install yfinance prior to importing
import yfinance as yf

# %%
# Create variable for single asset (stock)
bli = yf.Ticker("BLI")

# %%
# Get stock info
bli.info
# Out:
# {'zip': '94608',
#  'sector': 'Healthcare',
#  'fullTimeEmployees': 293,
#  'longBusinessSummary': 'Berkeley Lights, Inc., a digital cell biology company, focuses on enabling and accelerating the rapid development and commercialization of biotherapeutics and other cell-based products. The company offers an integrated platform, which comprise of proprietary consumables, including OptoSelect chips and reagent kits, automation systems, and application and workflow software. It serves in North America, the Asia Pacific, and Europe. Berkeley Lights, Inc. was incorporated in 2011 and is headquartered in Emeryville, California.',
#  'city': 'EmeryVille',
#  'phone': '510 858 2855',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.berkeleylights.com',
#  'maxAge': 1,
#  'address1': '5858 Horton Street',
#  'industry': 'Biotechnology',
#  'address2': 'Suite 320',
#  'ebitdaMargins': -0.88914,
#  'profitMargins': -0.98206,
# ...

# %%
# Get historical market data
hist = bli.history(period="max")

# %%
# Show financials
bli.financials
# Out:
#                                          2021-12-31   2020-12-31  2019-12-31  \
# Research Development                     58553000.0   47240000.0  38414000.0
# Effect Of Accounting Charges                   None         None        None
# Income Before Tax                       -71779000.0  -41410000.0 -18233000.0
# Minority Interest                              None         None        None
# Net Income                              -71724000.0  -41584000.0 -18302000.0
# Selling General Administrative           68787000.0   37709000.0  21599000.0
# Gross Profit                             56551000.0   44555000.0  43476000.0
# Ebit                                    -70789000.0  -40394000.0 -16537000.0
# Operating Income                        -70789000.0  -40394000.0 -16537000.0
# Other Operating Expenses                       None         None        None
# Interest Expense                         -1171000.0   -1436000.0  -1425000.0
# ...

# %%
# Show major holders
bli.major_holders
# Out:
#         0                                      1
# 0  15.32%        % of Shares Held by All Insider
# 1  68.63%       % of Shares Held by Institutions
# 2  81.04%        % of Float Held by Institutions
# 3     174  Number of Institutions Holding Shares

# %%
# Analysts recommendations
bli.recommendations
# Out:
#                                Firm        To Grade    From Grade Action
# Date
# 2020-08-11 10:00:19     Cowen & Co.      Outperform                 init
# 2020-08-11 12:43:31  Morgan Stanley    Equal-Weight                 init
# 2020-08-11 13:06:35       JP Morgan      Overweight                 init
# 2020-11-10 09:04:54         KeyBanc      Overweight                 init
# 2020-11-13 09:13:39         KeyBanc      Overweight                 main
# 2020-11-16 13:07:56  Morgan Stanley    Equal-Weight                 main
# 2021-01-27 10:53:03          Stifel             Buy                 init
# 2021-05-12 11:35:04  Morgan Stanley    Equal-Weight                 main
# 2021-06-22 09:28:18            BTIG             Buy                 init
# 2021-06-29 08:39:17         Keybanc   Sector Weight    Overweight   down
# 2021-08-12 11:46:14  Morgan Stanley    Equal-Weight                 main
# 2021-10-13 11:09:37       Berenberg             Buy                 init
# ...

# %%
# Recent news
bli.news
# Out:
# [{'uuid': 'e3ff09e6-ea57-30f0-8114-c79e7d07ab52',
#   'title': 'Berkeley Lights to Report Third Quarter 2022 Financial Results on November 8, 2022',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/berkeley-lights-report-third-quarter-200500436.html',
#   'providerPublishTime': 1666123500,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/COHvwWmN70ZOEMAR.0fsIA--~B/aD0xNDI7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/LpbKPvsh..gXuZAhuesSIg--~B/aD0xNDI7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/5d4734dd155de569b38ba82d98e04e77',
#      'width': 400,
#      'height': 142,
#      'tag': 'original'},
# ...
